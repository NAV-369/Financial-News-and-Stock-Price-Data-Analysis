# %%
import sys
import os

# Add the root directory of your project to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %% [markdown]
# ##### Import Required Libraries:

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from src.data_loader import load_data
from src.indicators import calculate_indicators
from src.visualize import plot_sma, plot_rsi, plot_macd

# %% [markdown]
# ##### Load Data:

# %%
data_folder = '/Users/zelalemtegene/Desktop/week_1/data'  # Update this path if needed
stock_data = load_data(data_folder)

# %%
import os
from src.data_loader import load_data

# Check the current working directory
print("Current working directory:", os.getcwd())

# Absolute path to the 'data' folder
data_folder = '/Users/zelalemtegene/Desktop/week_1/data'  # Adjusted to the correct path

# Load data from the 'data' folder
stock_data = load_data(data_folder)

# Display the first few rows to verify data loading
stock_data.head()
# Out:
# Current working directory: /Users/zelalemtegene/Desktop
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#             Dividends  Stock Splits                    source
# Date
# 1980-12-12        0.0           0.0  AAPL_historical_data.csv
# 1980-12-15        0.0           0.0  AAPL_historical_data.csv
# 1980-12-16        0.0           0.0  AAPL_historical_data.csv
# 1980-12-17        0.0           0.0  AAPL_historical_data.csv
# 1980-12-18        0.0           0.0  AAPL_historical_data.csv

# %% [markdown]
# ##### Calculate Technical Indicators:

# %%
# Calculate the technical indicators (SMA, RSI, MACD)
stock_data = calculate_indicators(stock_data)

# Display the first few rows to verify the indicators are added correctly
stock_data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#             Dividends  Stock Splits                    source  SMA_50  \
# Date
# 1980-12-12        0.0           0.0  AAPL_historical_data.csv     NaN
# 1980-12-15        0.0           0.0  AAPL_historical_data.csv     NaN
# 1980-12-16        0.0           0.0  AAPL_historical_data.csv     NaN
# 1980-12-17        0.0           0.0  AAPL_historical_data.csv     NaN
# 1980-12-18        0.0           0.0  AAPL_historical_data.csv     NaN
#
#             SMA_200  RSI  MACD  MACD_Signal  MACD_Hist
# Date
# ...

# %% [markdown]
# ##### Visualize the Data:

# %%
# Plot the Simple Moving Average (SMA)
plot_sma(stock_data)
# Plot the Relative Strength Index (RSI)
plot_rsi(stock_data)
# Plot the Moving Average Convergence Divergence (MACD)
plot_macd(stock_data)
# Out:
# /Users/zelalemtegene/Desktop/week_1/work-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##### Save/Commit Results

# %%
# Save the plots to files
plt.savefig('sma_plot.png')  # Save the SMA plot
plt.savefig('rsi_plot.png')  # Save the RSI plot
plt.savefig('macd_plot.png')  # Save the MACD plot

# %% [markdown]
# ##### Implement PyNance for Financial Metrics:

# %%
import pynance as pn

# Create a Ticker object using the desired stock symbol (e.g., 'AAPL' for Apple)
ticker = "AAPL"
stock = pn.Ticker(ticker)

# Get stock information (this contains various financial metrics)
stock_info = stock.info()

# Print stock data to check available metrics
print(stock_info)

# Extract some specific financial metrics (e.g., P/E ratio, dividend yield)
pe_ratio = stock_info.get('trailingPE', 'N/A')
dividend_yield = stock_info.get('dividendYield', 'N/A')

# Display the financial metrics
print(f"P/E Ratio: {pe_ratio}")
print(f"Dividend Yield: {dividend_yield}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       3 # Create a Ticker object using the desired stock symbol (e.g., 'AAPL' for Apple)
#       4 ticker = "AAPL"
# ----> 5 stock = pn.Ticker(ticker)
#       7 # Get stock information (this contains various financial metrics)
#       8 stock_info = stock.info()
#
# AttributeError: module 'pynance' has no attribute 'Ticker'
